# %% [markdown]
# # Practice Task: Plotly Map Visualization

# %% [markdown]
# Your task is to visually explore the World Development Indicator Dataset using Plotly Maps, and to reflect on perceptual problems and useful design choices.

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("wdi.csv")
df.head(2)
# Out:
#   iso3      country capital continent      region  year  population  gdp  \
# 0  AFG  Afghanistan   Kabul      Asia  South Asia  2000  19542982.0  NaN
# 1  AFG  Afghanistan   Kabul      Asia  South Asia  2001  19688632.0  NaN
#
#    gdp_capita  life_expectancy  fertility  maternal_death_risk  \
# 0         NaN           55.298      7.534            10.443196
# 1         NaN           55.798      7.446             9.488699
#
#    infant_mortality_1000  greenhousegas_capita
# 0                   90.6           14205.32527
# 1                   88.0           12604.75975

# %% [markdown]
# ## Task 1
# Create choropleth maps for different variables (numerical and categorical) and the year 2020?

# %% [markdown]
# # Task 2
# For a variable of your choice from above, try out a Plotly symbol map (scatter_geo). Which map type works better?

# %% [markdown]
# ## Task 3
# Pick a single choropleth visualization from above, and experiment with different color scales. Which color scale works best?

# %% [markdown]
# ## Exercise 4
# Visualize the change a variables of your choice between the 2000 and 2020 using a map? What are interesting patterns that can be observed?
